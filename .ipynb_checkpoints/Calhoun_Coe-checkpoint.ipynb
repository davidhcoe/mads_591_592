# %%
import pandas as pd

def text_to_pct(txt):
  if len(txt) == 1:
    txt = '0'+txt

  return float('.{}'.format(txt))

def clean_nci(row):
  #use index instead of names because of encoding issues
  row[1] = text_to_pct(row[1].split('%')[0])
  row[2] = text_to_pct(row[2].split('%')[0])
  row[3] = text_to_pct(row[3].split('%')[0])
  row[4] = text_to_pct(row[4].split('%')[0])
  row[5] = text_to_pct(row[5].split('%')[0])
  
  return row

df_acs = pd.read_csv('https://raw.githubusercontent.com/davidhcoe/mads_591_592/master/data/ACS/ACSDT1Y2010.B18131_data_with_overlays_2020-08-29T124705.csv')
df_nber = pd.read_csv('https://raw.githubusercontent.com/davidhcoe/mads_591_592/master/data/NBER/cbsa2fipsxw.csv')
df_nci = pd.read_csv('https://raw.githubusercontent.com/davidhcoe/mads_591_592/master/data/NCI/NCI_tbl27.csv', encoding = "ISO-8859-1", engine='python')
df_nci = df_nci.apply(clean_nci, axis=1)
df_nci.columns = [['State','None','Limited','Full','Has_Unknown_Level','Unknown','N']]
df_nci
# Out:
#           State  None Limited  Full Has_Unknown_Level Unknown      N
# 0            AL  0.72    0.02  0.25              0.01    0.00    381
# 1            AZ  0.35    0.04  0.58              0.03    0.01    491
# 2            AR  0.45    0.05  0.47              0.02    0.01    395
# 3            CA  0.79    0.21  0.00              0.00    0.00   8275
# 4            CO  0.46    0.00  0.37              0.04    0.12    405
# 5            CT  0.16    0.11  0.73              0.00    0.00    371
# 6            DE  0.94    0.00  0.05              0.00    0.00    415
# 7            DC  0.21    0.23  0.27              0.21    0.08    414
# 8            FL  0.68    0.13  0.19              0.00    0.00    957
# 9            GA  0.84    0.01  0.14              0.01    0.00    472
# 10           IL  0.33    0.07  0.59              0.00    0.00    368
# 11           IN  0.47    0.01  0.49              0.03    0.00    739
# 12           KS  0.37    0.03  0.59              0.01    0.00    386
# ...
